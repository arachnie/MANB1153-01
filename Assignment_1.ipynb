# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import  seaborn as sns
import numpy as np
LARGE_FIGSIZE = (12, 8)

# %% [markdown]
# ## Inline plots

# %%
# %matplotlib inline

# %% [markdown]
# ## Reading the data

# %%
df = pd.read_csv('/Users/aliodayzuhair/Downloads/Telco-Customer-Churn.csv')

# %% [markdown]
# ## Show the 10 first rows

# %%
df.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
# 9  6388-TABGU    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity  ...   DeviceProtection  \
# ...

# %% [markdown]
# ## The shape of the dataframe

# %%
df.shape
# Out:
# (7043, 21)

# %% [markdown]
# ## Info about the Dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
# customerID          7043 non-null object
# gender              7043 non-null object
# SeniorCitizen       7043 non-null int64
# Partner             7043 non-null object
# Dependents          7043 non-null object
# tenure              7043 non-null int64
# PhoneService        7043 non-null object
# MultipleLines       7043 non-null object
# InternetService     7043 non-null object
# OnlineSecurity      7043 non-null object
# OnlineBackup        7043 non-null object
# DeviceProtection    7043 non-null object
# TechSupport         7043 non-null object
# StreamingTV         7043 non-null object
# StreamingMovies     7043 non-null object
# Contract            7043 non-null object
# PaperlessBilling    7043 non-null object
# PaymentMethod       7043 non-null object
# MonthlyCharges      7043 non-null float64
# TotalCharges        7032 non-null float64
# ...

# %% [markdown]
# ## Set the index customerID column

# %%
df = df.set_index('customerID')

# %%
df.head()
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No       1           No
# 5575-GNVDE    Male              0      No         No      34          Yes
# 3668-QPYBK    Male              0      No         No       2          Yes
# 7795-CFOCW    Male              0      No         No      45           No
# 9237-HQITU  Female              0      No         No       2          Yes
#
#                MultipleLines InternetService OnlineSecurity OnlineBackup  \
# customerID
# 7590-VHVEG  No phone service             DSL             No          Yes
# 5575-GNVDE                No             DSL            Yes           No
# 3668-QPYBK                No             DSL            Yes          Yes
# 7795-CFOCW  No phone service             DSL            Yes           No
# 9237-HQITU                No     Fiber optic             No           No
#
# ...

# %% [markdown]
# ## Boxplot of the TotalCharges column

# %%
df.boxplot(column='TotalCharges')

# %% [markdown]
# ## Boxplot of the MonthlyCharges column

# %%
df.boxplot('MonthlyCharges')

# %% [markdown]
# ## Monthly Charges distribution

# %%
sns.distplot(df['MonthlyCharges'].dropna(), hist=True, kde=True, rug=False, bins=25);
# Out:
# /Users/aliodayzuhair/anaconda/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# ## Relationship between TechSupport and Churn columns

# %%
pd.crosstab(df["TechSupport"],df["Churn"],margins=True)
# Out:
# Churn                  No   Yes   All
# TechSupport
# No                   2027  1446  3473
# No internet service  1413   113  1526
# Yes                  1734   310  2044
# All                  5174  1869  7043

# %% [markdown]
# ## Relationship between Contract and Churn columns

# %%
pd.crosstab(df["Contract"],df["Churn"],margins=True)
# Out:
# Churn             No   Yes   All
# Contract
# Month-to-month  2220  1655  3875
# One year        1307   166  1473
# Two year        1647    48  1695
# All             5174  1869  7043

# %% [markdown]
# ## Relationship between InternetService and Churn columns

# %%
def percConvert(ser):
  return ser/float(ser[-1])*100
pd.crosstab(df["InternetService"],df["Churn"],margins=True).apply(percConvert, axis=1)
# Out:
# Churn                   No        Yes    All
# InternetService
# DSL              81.040892  18.959108  100.0
# Fiber optic      58.107235  41.892765  100.0
# No               92.595020   7.404980  100.0
# All              73.463013  26.536987  100.0

# %% [markdown]
# ## Normalization

# %%
df['Churn_norm'] = df.Churn.map({'Yes':1,'No':0}) 
df['InternetService_norm'] = df.InternetService.map({'No':0,'DSL':1,'Fiber optic':2})
df.head()
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No       1           No
# 5575-GNVDE    Male              0      No         No      34          Yes
# 3668-QPYBK    Male              0      No         No       2          Yes
# 7795-CFOCW    Male              0      No         No      45           No
# 9237-HQITU  Female              0      No         No       2          Yes
#
#                MultipleLines InternetService OnlineSecurity OnlineBackup  \
# customerID
# 7590-VHVEG  No phone service             DSL             No          Yes
# 5575-GNVDE                No             DSL            Yes           No
# 3668-QPYBK                No             DSL            Yes          Yes
# 7795-CFOCW  No phone service             DSL            Yes           No
# 9237-HQITU                No     Fiber optic             No           No
#
# ...

# %% [markdown]
# ## Correlation

# %%
df.corr()
# Out:
#                       SeniorCitizen    tenure  MonthlyCharges  TotalCharges  \
# SeniorCitizen              1.000000  0.016567        0.220173      0.102411
# tenure                     0.016567  1.000000        0.247900      0.825880
# MonthlyCharges             0.220173  0.247900        1.000000      0.651065
# TotalCharges               0.102411  0.825880        0.651065      1.000000
# Churn_norm                 0.150889 -0.352229        0.193356     -0.199484
# InternetService_norm       0.259390  0.033230        0.905491      0.428212
#
#                       Churn_norm  InternetService_norm
# SeniorCitizen           0.150889              0.259390
# tenure                 -0.352229              0.033230
# MonthlyCharges          0.193356              0.905491
# TotalCharges           -0.199484              0.428212
# Churn_norm              1.000000              0.316846
# InternetService_norm    0.316846              1.000000
